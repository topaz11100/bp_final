# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time

# %%
import pandas as pd
import numpy as np

# 예제 데이터프레임 생성
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

# 추가할 배열 생성 (각 원소가 배열인 리스트)
new_column = [[1,2],[3,4],[5,6]]

# 새로운 열 'C'를 추가하고 배열을 설정
df['C'] = new_column
for i in df.loc[0,"C"]:
    print(i)
# Out:
# 1
# 2

# %%
a=pd.DataFrame([[1,2,3],[4,5,6]])
a.index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 a=pd.DataFrame([[1,2,3],[4,5,6]])
# ----> 2 a.index()
#
# TypeError: 'RangeIndex' object is not callable

# %%
df = pd.DataFrame({
    'A': ['foo', 'bar', 'baz'],
    'B': ['one', 'two', 'three'],
    'C': [1, 2, 3]
})



df.index=['a','q','w']
df.loc['w','B']
# Out:
# 'three'

# %%
NS_DIFF_1M = 0.000007
EW_DIFF_1M = 0.000009
PATROL_HR = 900
GRID_DIFF = 90
data_path = "data/"
encoding = "utf-8-sig"
#상계1
police = np.array([37.679699, 127.055066])

# %%
def filtering(police, grid):
    ft = (grid - police).copy()
    ft[:,0] /= NS_DIFF_1M
    ft[:,1] /= EW_DIFF_1M
    ft = np.sqrt( np.sum( np.square(ft), axis=1 ))
    grid = grid[ft <= PATROL_HR + 10, :]
    return grid

# %%
def grids(police):
    hcount = PATROL_HR//GRID_DIFF
    ew = np.arange(-hcount, hcount + 1, dtype=np.float64)
    ns = ew.reshape(-1,1).copy()
    ew *= EW_DIFF_1M * GRID_DIFF
    ns *= NS_DIFF_1M * GRID_DIFF
    
    result = np.full((2*hcount+1, 2*hcount+1, 2), police, dtype=np.float64)
    result[:,:,0] += ns
    result[:,:,1] += ew
    
    return filtering(police, result.reshape(-1,2))

# %%
def draw_marker(m, grid):
    for i in grid:
        folium.CircleMarker(location=i, radius=10, color='#000000').add_to(m)

# %%
m = folium.Map(location = police, zoom_start=60)
folium.Marker(location=police, 
              popup='지구대',
              icon=folium.Icon(color='lightblue', icon='star')
).add_to(m)

# %%
police_grid = grids(police)
draw_marker(m, police_grid)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca41cb2cc058183fa0de533e052fded2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca41cb2cc058183fa0de533e052fded2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca41cb2cc058183fa0de533e052fded2 = L.map(
#                 &quot;map_ca41cb2cc058183fa0de533e052fded2&quot;,
#                 {
#                     center: [37.679699, 127.055066],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 60,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d48966fc8114a5306cf55e745bbea3e2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d48966fc8114a5306cf55e745bbea3e2.addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var marker_3693b3cede8f45c081e4aede2367a24f = L.marker(
#                 [37.679699, 127.055066],
#                 {}
#             ).addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var icon_27ce9b3220e25f5bc4e84ed2196fe899 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3693b3cede8f45c081e4aede2367a24f.setIcon(icon_27ce9b3220e25f5bc4e84ed2196fe899);
#
#
#         var popup_c3ed717406c139f76e1c2b291a2aa9a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fdf375edea4be33122101dc0dad73c1 = $(`&lt;div id=&quot;html_7fdf375edea4be33122101dc0dad73c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;지구대&lt;/div&gt;`)[0];
#                 popup_c3ed717406c139f76e1c2b291a2aa9a9.setContent(html_7fdf375edea4be33122101dc0dad73c1);
#
#
#
#         marker_3693b3cede8f45c081e4aede2367a24f.bindPopup(popup_c3ed717406c139f76e1c2b291a2aa9a9)
#         ;
#
#
#
#
#             var circle_marker_b1b7ebb909b0eeeb9b0743b968e15b90 = L.circleMarker(
#                 [37.673398999999996, 127.054256],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var circle_marker_512f542787f70afb957aa874949e2049 = L.circleMarker(
#                 [37.673398999999996, 127.055066],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var circle_marker_8a6c9404fba736651a3053438b3fa518 = L.circleMarker(
#                 [37.673398999999996, 127.055876],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var circle_marker_e1321d9fb82befa159727a2581256e8b = L.circleMarker(
#                 [37.674029, 127.05182599999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ca41cb2cc058183fa0de533e052fded2);
#
#
#             var circle_marker_32b0cb124e849def3278d1281746ebe3 = L.circleMarker(
#                 [37.674029, 127.05263599999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&qu

# %%
#police_grid_data = pd.DataFrame(police_grid, columns=["위도", "경도"])
#police_grid_data.to_csv("상계1위경도.csv", index=False, encoding=encoding)

# %%
police_grid_data=pd.read_csv(data_path+"상계1주소.csv", encoding=encoding)
police_grid_data["유형"] = None
police_grid_data
# Out:
#             위도          경도                   지번주소                    도로명주소  \
# 0    37.673399  127.054256     서울특별시 노원구 상계동 1044     서울특별시 노원구 동일로231길 24
# 1    37.673399  127.055066   서울특별시 노원구 상계동 1044-2       서울특별시 노원구 동일로 1625
# 2    37.673399  127.055876  서울특별시 노원구 상계동 1025-40       서울특별시 노원구 동일로 1624
# 3    37.674029  127.051826   서울특별시 노원구 상계동 1094-5  서울특별시 노원구 동일로237길 68-16
# 4    37.674029  127.052636  서울특별시 노원구 상계동 1048-51    서울특별시 노원구 동일로237다길 11
# ..         ...         ...                    ...                      ...
# 320  37.685369  127.057496     서울특별시 노원구 상계동 산 15       서울특별시 노원구 동일로 1742
# 321  37.685369  127.058306     서울특별시 노원구 상계동 산 16  서울특별시 노원구 동일로250길 39-68
# 322  37.685999  127.054256     서울특별시 노원구 상계동 1313         서울특별시 노원구 누원로 18
# 323  37.685999  127.055066   서울특별시 노원구 상계동 1314-4         서울특별시 노원구 누원로 28
# 324  37.685999  127.055876   서울특별시 노원구 상계동 산 12-1       서울특별시 노원구 동일로 1772
#
#        유형
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 320  None
# 321  None
# 322  None
# 323  None
# 324  None
#
# [325 rows x 5 columns]

# %%
DELAY_TIME = 1
map_url = "https://map.kakao.com/"

# %%
def openweb(mode="window"):
    if mode == "no":
        options = wb.ChromeOptions()
        options.add_argument('headless')
        driver = wb.Chrome(options=options)
    else:
        driver = wb.Chrome()
    driver.get(map_url)
    time.sleep(DELAY_TIME)
    return driver

# %%
def search(browser, address):
    search_box = browser.find_element(By.ID, "search.keyword.query")
    while search_box.get_attribute("value"):
        search_box.send_keys(Keys.CONTROL, 'a')
        search_box.send_keys(Keys.BACKSPACE)
    search_box.send_keys(address)
    search_box.send_keys(Keys.RETURN)
    time.sleep(DELAY_TIME)

# %%
def find_postage(browser, num_addr):
    if "산" in num_addr:
        return "nozip"
    search(browser, num_addr)
    try:
        postage = browser.find_element(By.CLASS_NAME, "zip")
    except NoSuchElementException:
        return "nozip"
    else:
        return postage.text
    
def find_build_name(browser, road_addr, num_addr):
    search(browser, road_addr)
    try:
        buildname = browser.find_element(By.CLASS_NAME, "building")
    except NoSuchElementException:
        return find_postage(browser, num_addr)
    else:
        return buildname.text

# %%
#browser = openweb("no")

# %%
#for i in police_grid_data.index:
    #police_grid_data.iloc[i, 4] = find_build_name(browser, police_grid_data.iloc[i, 3], police_grid_data.iloc[i, 2])

# %%
#police_grid_data.to_csv(data_path+"유형.csv",encoding=encoding)

# %%
import pandas as pd

# 데이터를 담은 리스트
data = [[1, 1], [1, 2], [1, 3]]

# 인덱스를 튜플로 구성하여 MultiIndex 생성
index = pd.MultiIndex.from_tuples([(1, 1), (1, 2), (1, 3)], names=['outer', 'inner'])

# 데이터프레임 생성
df = pd.DataFrame(data, index=index, columns=['A', 'B'])

# 결과 출력
df
# Out:
#              A  B
# outer inner
# 1     1      1  1
#       2      1  2
#       3      1  3

# %%
import pandas as pd

# 기존의 DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['1', '2', '3'])

# MultiIndex 생성
multi_index = pd.MultiIndex.from_tuples([(1, 1), (1, 2), (1, 3)], names=['outer', 'inner'])

# MultiIndex를 지정하여 데이터 추가
df = pd.DataFrame([[1], [2], [3]], index=multi_index, columns=['C']).combine_first(df)

# 결과 출력
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 10
#       7 multi_index = pd.MultiIndex.from_tuples([(1, 1), (1, 2), (1, 3)], names=['outer', 'inner'])
#       9 # MultiIndex를 지정하여 데이터 추가
# ---> 10 df = pd.DataFrame([[1], [2], [3]], index=multi_index, columns=['C']).combine_first(df)
#      12 # 결과 출력
#      13 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8551, in DataFrame.combine_first(self, other)
#    8549     combined = combined.astype(other.dtypes)
#    8550 else:
# -> 8551     combined = self.combine(other, combiner, overwrite=False)
#    8553 dtypes = {
#    8554     col: find_common_type([self.dtypes[col], other.dtypes[col]])
#    8555     for col in self.columns.intersection(other.columns)
#    8556     if combined.dtypes[col] != self.dtypes[col]
#    8557 }
#    8559 if dtypes:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8417, in DataFrame.combine(self, other, func, fill_value, overwrite)
#    8311 """
#    8312 Perform column-wise combine with another DataFrame.
#    8313
#    (...)
#    8413 2  NaN  3.0 1.0
#    8414 """
#    8415 other_idxlen = len(other.index)  # save for compare
# -> 8417 this, other = self.align(other, copy=False)
#    8418 new_index = this.index
#    8420 if other.empty and len(new_index) == len(self.index):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:10090, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10088     axis = self._get_axis_number(axis)
#   10089 if isinstance(other, ABCDataFrame):
# > 10090     left, _right, join_index = self._align_frame(
#   10091         other,
#   10092         join=join,
#   10093         axis=axis,
#   10094         level=level,
#   10095         copy=copy,
#   10096         fill_value=fill_value,
#   10097         method=method,
#   10098         limit=limit,
#   10099         fill_axis=fill_axis,
#   10100     )
#   10102 elif isinstance(other, ABCSeries):
#   10103     left, _right, join_index = self._align_series(
#   10104         other,
#   10105         join=join,
#    (...)
#   10112         fill_axis=fill_axis,
#   10113     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:10156, in NDFrame._align_frame(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10153 is_series = isinstance(self, ABCSeries)
#   10155 if (axis is None or axis == 0) and not self.index.equals(other.index):
# > 10156     join_index, ilidx, iridx = self.index.join(
#   10157         other.index, how=join, level=level, return_indexers=True
#   10158     )
#   10160 if (
#   10161     (axis is None or axis == 1)
#   10162     and not is_series
#   10163     and not self.columns.equals(other.columns)
#   10164 ):
#   10165     join_columns, clidx, cridx = self.columns.join(
#   10166         other.columns, how=join, level=level, return_indexers=True
#   10167     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:267, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     257 @functools.wraps(meth)
#     258 def join(
#     259     self,
#    (...)
#     265     sort: bool = False,
#     266 ):
# --> 267     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     268     if not return_indexers:
#     269         return join_index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4622, in Index.join(self, other, how, level, return_indexers, sort)
#    4620         pass
#    4621     else:
# -> 4622         return self._join_multi(other, how=how)
#    4624 # join on the level
#    4625 if level is not None and (self._is_multi or other._is_multi):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4745, in Index._join_multi(self, other, how)
#    4743 # need at least 1 in common
#    4744 if not overlap:
# -> 4745     raise ValueError("cannot join with no overlapping index names")
#    4747 if isinstance(self, MultiIndex) and isinstance(other, MultiIndex):
#    4748     # Drop the non-matching levels from left and right respectively
#    4749     ldrop_names = sorted(self_names - overlap, key=self_names_order)
#
# ValueError: cannot join with no overlapping index names

# %%
import pandas as pd

# 기존의 DataFrame
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]}, index=['1', '2', '3'])

# MultiIndex 생성
multi_index = pd.MultiIndex.from_tuples([(1, 1), (1, 2), (1, 3)], names=['outer', 'inner'])

# 기존 DataFrame의 인덱스를 MultiIndex로 변환
df.index = pd.MultiIndex.from_tuples([(i,) for i in df.index], names=['outer'])

# 새로운 DataFrame 생성
new_df = pd.DataFrame([[1], [2], [3]], index=multi_index, columns=['C'])

# 기존 DataFrame과 새로운 DataFrame 결합
result_df = new_df.combine_first(df)

# 결과 출력
result_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 16
#      13 new_df = pd.DataFrame([[1], [2], [3]], index=multi_index, columns=['C'])
#      15 # 기존 DataFrame과 새로운 DataFrame 결합
# ---> 16 result_df = new_df.combine_first(df)
#      18 # 결과 출력
#      19 result_df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8551, in DataFrame.combine_first(self, other)
#    8549     combined = combined.astype(other.dtypes)
#    8550 else:
# -> 8551     combined = self.combine(other, combiner, overwrite=False)
#    8553 dtypes = {
#    8554     col: find_common_type([self.dtypes[col], other.dtypes[col]])
#    8555     for col in self.columns.intersection(other.columns)
#    8556     if combined.dtypes[col] != self.dtypes[col]
#    8557 }
#    8559 if dtypes:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:8417, in DataFrame.combine(self, other, func, fill_value, overwrite)
#    8311 """
#    8312 Perform column-wise combine with another DataFrame.
#    8313
#    (...)
#    8413 2  NaN  3.0 1.0
#    8414 """
#    8415 other_idxlen = len(other.index)  # save for compare
# -> 8417 this, other = self.align(other, copy=False)
#    8418 new_index = this.index
#    8420 if other.empty and len(new_index) == len(self.index):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:10090, in NDFrame.align(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis, broadcast_axis)
#   10088     axis = self._get_axis_number(axis)
#   10089 if isinstance(other, ABCDataFrame):
# > 10090     left, _right, join_index = self._align_frame(
#   10091         other,
#   10092         join=join,
#   10093         axis=axis,
#   10094         level=level,
#   10095         copy=copy,
#   10096         fill_value=fill_value,
#   10097         method=method,
#   10098         limit=limit,
#   10099         fill_axis=fill_axis,
#   10100     )
#   10102 elif isinstance(other, ABCSeries):
#   10103     left, _right, join_index = self._align_series(
#   10104         other,
#   10105         join=join,
#    (...)
#   10112         fill_axis=fill_axis,
#   10113     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:10156, in NDFrame._align_frame(self, other, join, axis, level, copy, fill_value, method, limit, fill_axis)
#   10153 is_series = isinstance(self, ABCSeries)
#   10155 if (axis is None or axis == 0) and not self.index.equals(other.index):
# > 10156     join_index, ilidx, iridx = self.index.join(
#   10157         other.index, how=join, level=level, return_indexers=True
#   10158     )
#   10160 if (
#   10161     (axis is None or axis == 1)
#   10162     and not is_series
#   10163     and not self.columns.equals(other.columns)
#   10164 ):
#   10165     join_columns, clidx, cridx = self.columns.join(
#   10166         other.columns, how=join, level=level, return_indexers=True
#   10167     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:267, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     257 @functools.wraps(meth)
#     258 def join(
#     259     self,
#    (...)
#     265     sort: bool = False,
#     266 ):
# --> 267     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     268     if not return_indexers:
#     269         return join_index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4622, in Index.join(self, other, how, level, return_indexers, sort)
#    4620         pass
#    4621     else:
# -> 4622         return self._join_multi(other, how=how)
#    4624 # join on the level
#    4625 if level is not None and (self._is_multi or other._is_multi):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4762, in Index._join_multi(self, other, how)
#    4758     other_jnlevels = other.droplevel(rdrop_names)
#    4760 # Join left and right
#    4761 # Join on same leveled multi-index frames is supported
# -> 4762 join_idx, lidx, ridx = self_jnlevels.join(
#    4763     other_jnlevels, how=how, return_indexers=True
#    4764 )
#    4766 # Restore the dropped levels
#    4767 # Returned index level order is
#    4768 # common levels, ldrop_names, rdrop_names
#    4769 dropped_names = ldrop_names + rdrop_names
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:267, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     257 @functools.wraps(meth)
#     258 def join(
#     259     self,
#    (...)
#     265     sort: bool = False,
#     266 ):
# --> 267     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     268     if not return_indexers:
#     269         return join_index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4661, in Index.join(self, other, how, level, return_indexers, sort)
#    4659     this = self.astype(dtype, copy=False)
#    4660     other = other.astype(dtype, copy=False)
# -> 4661     return this.join(other, how=how, return_indexers=True)
#    4663 _validate_join_method(how)
#    4665 if not self.is_unique and not other.is_unique:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:267, in _maybe_return_indexers.<locals>.join(self, other, how, level, return_indexers, sort)
#     257 @functools.wraps(meth)
#     258 def join(
#     259     self,
#    (...)
#     265     sort: bool = False,
#     266 ):
# --> 267     join_index, lidx, ridx = meth(self, other, how=how, level=level, sort=sort)
#     268     if not return_indexers:
#     269         return join_index
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4673, in Index.join(self, other, how, level, return_indexers, sort)
#    4668 if self.is_monotonic_increasing and other.is_monotonic_increasing:
#    4669     if not isinstance(self.dtype, IntervalDtype):
#    4670         # otherwise we will fall through to _join_via_get_indexer
#    4671         # GH#39133
#    4672         # go through object dtype for ea till engine is supported properly
# -> 4673         return self._join_monotonic(other, how=how)
#    4674 else:
#    4675     return self._join_non_unique(other, how=how)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5020, in Index._join_monotonic(self, other, how)
#    5018     join_array, lidx, ridx = self._inner_indexer(other)
#    5019 elif how == "outer":
# -> 5020     join_array, lidx, ridx = self._outer_indexer(other)
#    5022 assert lidx is not None
#    5023 assert ridx is not None
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:421, in Index._outer_indexer(self, other)
#     419 sv = cast(np.ndarray, sv)
#     420 ov = cast(np.ndarray, ov)
# --> 421 joined_ndarray, lidx, ridx = libjoin.outer_join_indexer(sv, ov)
#     422 joined = self._from_join_target(joined_ndarray)
#     423 return joined, lidx, ridx
#
# File join.pyx:580, in pandas._libs.join.outer_join_indexer()
#
# TypeError: '<' not supported between instances of 'int' and 'str'
